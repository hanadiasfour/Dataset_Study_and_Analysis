# %% [markdown]
# # Welcome to Video Game Sales Dataset Analysis

# %% [markdown]
# ## <font color='blue'>Description of the Video Game Sales Dataset:</font>
#
# This dataset contains information about video games with sales greater than 100,000 copies. There are 11 features and 16,598 records. It was generated by scraping data from vgchartz.com. The source of this dataset is Kaggle.com under the title "Video Game Sales". Link to dataset: https://www.kaggle.com/datasets/gregorut/videogamesales
#
#
# ### <font color='blue'> Dictionary of Columns:</font>
#
# 1. **Rank**
#    - Data Type: Integer
#    - Description: Ranking of overall sales.
#
# 2. **Name**
#    - Data Type: String
#    - Description: The name of the game.
#
# 3. **Platform**
#    - Data Type: String
#    - Description: The platform on which the game was released.
#
# 4. **Year**
#    - Data Type: Integer
#    - Description: The year of the game's release.
#
# 5. **Genre**
#    - Data Type: String
#    - Description: The genre of the game.
#
# 6. **Publisher**
#    - Data Type: String
#    - Description: The publisher of the game.
#
# 7. **NA_Sales**
#    - Data Type: Float
#    - Description: Sales in North America (in millions).
#
# 8. **EU_Sales**
#    - Data Type: Float
#    - Description: Sales in Europe (in millions).
#
# 9. **JP_Sales**
#    - Data Type: Float
#    - Description: Sales in Japan (in millions).
#
# 10. **Other_Sales**
#     - Data Type: Float
#     - Description: Sales in the rest of the world (in millions).
#
# 11. **Global_Sales**
#     - Data Type: Float
#     - Description: Total worldwide sales (in millions).

# %% [markdown]
# ### <font color='blue'>Importing the necessary libraries: </font>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### <font color='blue'>Loading the data of video game sales from CSV file:</font>

# %%
# Read data from csv file
data = pd.read_csv('vgsales.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### <font color='blue'>Displaying the shape of the video game sales data: </font>

# %%
data.shape
# Out:
# (16598, 11)

# %% [markdown]
# <font color='green'>This means that the data set is two dimentional with 11 features (columns) and 16,598 records (rows).</font>

# %% [markdown]
# ### <font color='blue'>Checking whether the dataset contains any missing data values: </font>

# %%
# Generating a boolean DataFrame which shows true for any NA values
is_NA = data.isna()
# Using the sum method to count the number of true values in the boolean data set
is_NA.sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# <font color='green'>This Series shows that there are 271 missing values in the Year feature and 58 other missing values in the Publisher feature. This gives us a total of 329 missing data points in this data set.</font>

# %% [markdown]
# ### <font color='blue'>Which features are numerical, and which are nominal, and which are ordinal ?</font>
#
# 1. **<font color='red'>Numerical Features:</font>** In the dataset, numerical features include:
#    - NA_Sales (Float)
#    - EU_Sales (Float)
#    - JP_Sales (Float)
#    - Other_Sales (Float)
#    - Global_Sales (Float)
#
#    **<font color='green'> Since they represent quantitative data and can be measured or counted.</font>**
#
#
# 2. **<font color='red'>Nominal Features</font>**: In the dataset, the nominal features include:
#    - Name (String)
#    - Platform (String)
#    - Genre (String)
#    - Publisher (String)
#
#    **<font color='green'>Since they represent discrete values without any inherent order.</font>**
#
#
# 3. **<font color='red'>Ordinal Features</font>**: In the dataset, the ordinal features are:
#     - Rank (Integer)
#     - Year (Integer)
#
#     **<font color='green'>This feature has a clear ordering or ranking between the values.</font>**

# %% [markdown]
# ### <font color='blue'>Two numerical features are chosen to describe and interpert their statistics.</font>

# %% [markdown]
# - ### <font color='blue'>First feature:</font>

# %%
#First feature is the Japan sales
num_feature_1 = data["JP_Sales"]
num_feature_1.describe()
# Out:
# count    16598.000000
# mean         0.077782
# std          0.309291
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_Sales, dtype: float64

# %% [markdown]
# ### <font color='green'>According to the descrition provided above about Japan's video game sales, we can conclude the following:</font>
# - There are **16,598 records** available for Japan sales. This matches the number of rows in the dataset, meaning there are **no missing values here**.
# - The average Japan sales per game is approximately **0.078 million units**.
# - The sales figures **are less spread out around the mean**, with a standard deviation of approximately **0.309 million units**.
# - The lowest recorded sales figure is **0 million units**, indicating that **some games did not sell in Japan**.
# - **25%** of games sold **0 million units or less** in Japan (25th Percentile).
# - The median sales is **0 million units**. In other words, **half of the games sold less than this amount** in Japan.
# - **75%** of games sold **0.04 million units or less** in Japan (75th Percentile).
# - The **highest recorded sales figure is 10.22 million units**, representing the **best-selling game** in Japan.

# %% [markdown]
# ### <font color='blue'>Calculating the skewness:</font>

# %%
#Japan Sales skewness
num_feature_1.skew()
# Out:
# 11.206458372215543

# %% [markdown]
# <font color='green'>Japan's sales column has skewness of value of 11.21. This large positive skewness shows that the distribution is heavily right-skewed, meaning that there are a few games with very high sales figures that are pulling the distribution to the right.</font>
#
# #### **<font color='blue'> This skewness can be seen in the histogram below. The magority of sales are on the left of the graph (skewed to the right)</font>**

# %%
#creating the histogram for Japans sales column
plt.figure(figsize=(6, 100))
plt.hist(num_feature_1, bins=60, color='pink', edgecolor='black')
plt.grid(True)
plt.show()

# %% [markdown]
# - ### <font color='blue'>Second feature:</font>

# %%
#Second feature is the global sales
num_feature_2 = data["Global_Sales"]
num_feature_2.describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ### <font color='green'>According to the description provided above about global video game sales, we can conclude the following:</font>
# - There are **16,598 records** available for global sales. This also matches the number of rows indicating **no missing values**.
# - The average global sales per game is approximately 0.537 million units.
# - The sales figures **vary widely around the mean**, with a standard deviation of approximately **1.555 million units.**
# - The lowest recorded sales figure is **0.01 million units.**
# - **25%** of games sold **0.06 million units or less** globally (25th Percentile).
# - The median sales is **0.17 million units** showing that **half of the games sold less than this amount globally**.
# - **75%** of games sold **0.47 million units or less** globally (75th Percentile).
# - The **highest recorded sales figure is 82.74 million units**, representing the **best-selling game globally**.

# %% [markdown]
# ### <font color='blue'>Calculating the skewness:</font>

# %%
#Global Sales skewness
num_feature_2.skew()
# Out:
# 17.400645097552452

# %% [markdown]
# <font color='green'>Global sales column has skewness of value of 17.40. This large positive skewness shows that the distribution is also heavily right-skewed, meaning that there are a few games with very high sales figures that are pulling the distribution to the right.</font>
#
# #### **<font color='blue'> This skewness can be seen in the histogram below. The magority of sales are on the left of the graph (skewed to the right)</font>**

# %%
#creating the histogram for global sales column
plt.figure(figsize=(6, 30))
plt.hist(num_feature_2, bins=50, color='pink', edgecolor='black')
plt.grid(True)
plt.show()

# %% [markdown]
# ### <font color='blue'>Two categorical features are chosen to determine their balance.</font>
#
# - ### <font color='blue'>First feature:</font>

# %%
#First Categorical feature is the Platform
cat_feature_1 = data["Platform"]
# Calculating the percentage which each unique platform value appeared in the column
cat_feature_1_percentages = (cat_feature_1.value_counts() / cat_feature_1.count()) *100
cat_feature_1_percentages
# Out:
# Platform
# DS      13.031691
# PS2     13.019641
# PS3      8.006989
# Wii      7.982890
# X360     7.621400
# PSP      7.308109
# PS       7.205687
# PC       5.783829
# XB       4.964454
# GBA      4.952404
# GC       3.349801
# 3DS      3.066635
# PSV      2.488252
# PS4      2.024340
# N64      1.921918
# SNES     1.439933
# XOne     1.283287
# SAT      1.042294
# WiiU     0.861550
# 2600     0.801301
# NES      0.590433
# GB       0.590433
# DC       0.313291
# GEN      0.162670
# NG       0.072298
# SCD      0.036149
# WS       0.036149
# 3DO      0.018074
# TG16     0.012050
# GG       0.006025
# PCFX     0.006025
# Name: count, dtype: float64

# %% [markdown]
# <font color="green">The Platform feature is not balanced. For example, the DS platform represents approximately 13.03% of the total platforms in that column while the NES platform represents only 0.59% approximately.</font>

# %% [markdown]
# - ### <font color='blue'>Second feature:</font>

# %%
#Second Categorical feature is the Genre
cat_feature_2 = data["Genre"]
# Calculating the percentage which each unique genre value appeared in the column
cat_feature_2_percentages = (cat_feature_2.value_counts() / cat_feature_2.count()) *100
cat_feature_2_percentages
# Out:
# Genre
# Action          19.978311
# Sports          14.134233
# Misc            10.477166
# Role-Playing     8.964936
# Shooter          7.892517
# Adventure        7.747921
# Racing           7.525003
# Platform         5.337993
# Simulation       5.223521
# Fighting         5.109049
# Strategy         4.102904
# Puzzle           3.506447
# Name: count, dtype: float64

# %% [markdown]
# <font color="green">The Genre feature is also not balanced. For example, the Action category represents approximately 19.98% of the genres in that column while the Fighting category represents only 5.11% approximately.</font>

# %% [markdown]
# ### <font color='blue'>Based on intuition, the two features NA_Sales (North America Sales) and EU_Sales (Europe Sales) could be correlated.</font>
#
# Logically, if a certain game is popular(has high sales) among the North American audiance, then the Europian people will also like this game and therefore its sales there will increase too. In other words, I expect the NA_Sales and EU_Sales features to have a positive relation.
#
# ### <font color='blue'>To verify whether this is true, two methods are used:</font>
# - <font color='blue'>Visualize relation</font>

# %%
# We can visualize the relation by using a scatter plot
data.plot.scatter(x='EU_Sales', y='NA_Sales');

# %% [markdown]
# <font color='green'>The scatter plot shows a positive relationship. The data is clustered togther, then gradually spreads diagonally to the top right, indicating that sales figures increase together in both regions.</font>
#
# - <font color='blue'>Correlation coefficient</font>

# %%
#Obtaining the numerical data only from the dataset
numerical_data = data.select_dtypes(include=['int64', 'float64'])

#generating the correlation coefficient for the chosen two features only
numerical_data[['NA_Sales','EU_Sales']].corr()
# Out:
#           NA_Sales  EU_Sales
# NA_Sales  1.000000  0.767727
# EU_Sales  0.767727  1.000000

# %% [markdown]
# <font color='green'>The correlation coefficients is 0.767727, indicating a strong positive correlation between the two features. This suggests that as sales increase in North America, they tend to increase in Europe as well, and vice versa. This measure agrees with the observation from the scatter plot earlier.</font>
#
# **Both tests agree with the initial assumption that the NA_Sales and EU_Sales of video games has a positive relation.**

# %% [markdown]
# ### <font color='blue'>Are their features that can be used as index?</font>

# %%
# Getting the number of duplicated ranks
data['Rank'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='green'>All data in the Rank column is a unique, since the summation of duplicated values is equal to zero. Each game occupies one rank in the list, meaning there are no two games with the same ranking. This makes the Rank appropriate to become a key for the dataset.</font>

# %%
# Setting the key of the dataset to the Rank column
data.index = data['Rank']
data
# Out:
#         Rank                                              Name Platform  \
# Rank
# 1          1                                        Wii Sports      Wii
# 2          2                                 Super Mario Bros.      NES
# 3          3                                    Mario Kart Wii      Wii
# 4          4                                 Wii Sports Resort      Wii
# 5          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16596  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16597  16597                     Men in Black II: Alien Escape       GC
# 16598  16598  SCORE International Baja 1000: The Official Game      PS2
# 16599  16599                                        Know How 2       DS
# 16600  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# ...
